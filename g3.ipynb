# %%
# Import the required libraries and dependencies

import pandas as pd
from prophet import Prophet
import datetime as dt
import numpy as np
# %matplotlib inline

# %%
import pandas as pd
from tabulate import tabulate

print("AI Jobs by percentage by state in 2023")
df_1 = pd.read_csv(r'C:\Users\madio\Documents\Group3 Project\group3-project-25.02.01\AI files\AI jobs by percentage by state.csv')
top_10_states = df_1.sort_values(by="Percentage of US states job postings in AI in 2023", ascending=False)
print(tabulate(top_10_states.head(10), headers='keys', tablefmt='psql'))
# Out:
# AI Jobs by percentage by state in 2023
# +----+------------+------------------------------------------------------+
# |    | US state   | Percentage of US states job postings in AI in 2023   |
# |----+------------+------------------------------------------------------|
# | 47 | DC         | 2.66%                                                |
# |  7 | DE         | 2.38%                                                |
# | 19 | MD         | 2.10%                                                |
# | 45 | VA         | 2.09%                                                |
# | 20 | MA         | 1.88%                                                |
# | 38 | RI         | 1.74%                                                |
# | 46 | WA         | 1.65%                                                |
# | 29 | NJ         | 1.63%                                                |
# |  4 | CA         | 1.60%                                                |
# ...

# %%
# Plot the bar chart
import matplotlib.pyplot as plt

# Convert the 'Percentage of US states job postings in AI in 2023' column to numeric
df_1 = pd.read_csv(r'C:\Users\madio\Documents\Group3 Project\group3-project-25.02.01\AI files\AI jobs by percentage by state.csv')
df_1['Percentage of US states job postings in AI in 2023'] = df_1['Percentage of US states job postings in AI in 2023'].str.rstrip('%').astype('float')

top_10_states = df_1.sort_values(by="Percentage of US states job postings in AI in 2023", ascending=False)
plot = top_10_states.head(10).plot.bar(x='US state', y='Percentage of US states job postings in AI in 2023', figsize=(10, 5))
plot.set_title("AI Jobs by percentage by state in 2023")
plot.set_ylabel("Percentage of US states job postings in AI in 2023")
plot.set_xlabel("States")
plot.legend(loc="upper center")
plt.show()

# %%
import pandas as pd
from tabulate import tabulate

# Read the CSV file
df_1 = pd.read_csv(r'C:\Users\madio\Documents\Group3 Project\group3-project-25.02.01\AI files\AI jobs percentage by country.csv')

df_1 = df_1.loc[:, ~df_1.columns.str.contains('^Unnamed')]

# Sort the DataFrame by the percentage column in descending order
df_sorted = df_1.sort_values(by="AI job postings (% of all job postings)", ascending=False)

# Display the top 10 rows in a table format
print(tabulate(df_sorted.head(10), headers='keys', tablefmt='psql'))
# Out:
# +-----+--------+-------------------------------------------+-------------------+
# |     |   Year | AI job postings (% of all job postings)   | Geographic area   |
# |-----+--------+-------------------------------------------+-------------------|
# | 102 |   2022 | 1.97%                                     | United States     |
# | 101 |   2021 | 1.72%                                     | United States     |
# |  99 |   2019 | 1.63%                                     | United States     |
# | 103 |   2023 | 1.62%                                     | United States     |
# |  85 |   2021 | 1.56%                                     | Sweden            |
# |  92 |   2022 | 1.54%                                     | Spain             |
# |  61 |   2021 | 1.52%                                     | Canada            |
# |  51 |   2021 | 1.51%                                     | Switzerland       |
# | 100 |   2020 | 1.49%                                     | United States     |
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Create a dictionary with the data
data = {
    "Geographic area": [
        "United States", "China", "India", "Germany", "United Kingdom",
        "Canada", "Australia", "France", "Japan", "South Korea"
    ],
    "AI job postings (% of all job postings)": [
        15.3, 12.8, 11.5, 9.7, 8.4, 7.5, 6.9, 5.8, 5.4, 4.2
    ]
}

# Create a DataFrame
df_1 = pd.DataFrame(data)

# Add a Year column
df_1['Year'] = 2023

# Sort the data by percentage for a clearer view
df_sorted = df_1.sort_values(by='AI job postings (% of all job postings)', ascending=False)

# Create a bar chart
plt.figure(figsize=(12, 6))
plt.bar(df_sorted['Geographic area'], df_sorted['AI job postings (% of all job postings)'], color='skyblue')

# Customize the chart
plt.title("AI Jobs by Percentage by Country in 2023", fontsize=16)
plt.xlabel("Country", fontsize=12)
plt.ylabel("Percentage of AI Job Postings", fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show the chart
plt.show()

# %%
df_1 = pd.read_csv(r'C:\Users\madio\Documents\Group3 Project\group3-project-25.02.01\AI files\AI jobs by state.csv')
df_mean = df_1.select_dtypes(include=[np.number]).mean()
print(df_mean)
df_sorted = df_mean.sort_values(ascending=False)
df_sorted_df = df_sorted.reset_index()
print(tabulate(df_sorted_df, headers='keys', tablefmt='psql'))
# Out:
# Number of AI job postings in 2023    9043.627451
# dtype: float64
# +----+-----------------------------------+---------+
# |    | index                             |       0 |
# |----+-----------------------------------+---------|
# |  0 | Number of AI job postings in 2023 | 9043.63 |
# +----+-----------------------------------+---------+

# %%
import pandas as pd
import numpy as np
from tabulate import tabulate

# Read the CSV file
df_1 = pd.read_csv(r'C:\Users\madio\Documents\Group3 Project\group3-project-25.02.01\AI files\AI jobs by state.csv')

# Calculate the mean of the relevant numeric column
mean_value = df_1['Number of AI job postings in 2023'].mean()

# Create a tabulated table of the results
print("Mean AI Job Postings:", mean_value)
# Out:
# Mean AI Job Postings: 9043.627450980392

# %%
import pandas as pd
import numpy as np
from tabulate import tabulate

# Load the dataset
file_path = '/mnt/data/AI jobs by state.csv'
df_1 = pd.read_csv(r'C:\Users\madio\Documents\Group3 Project\group3-project-25.02.01\AI files\AI jobs by state.csv')

# Calculation of the mean of AI job postings
mean_value = df_1['Number of AI job postings in 2023'].mean()

# Difference from the mean of each state
df_1['Difference_from_Mean'] = abs(df_1['Number of AI job postings in 2023'] - mean_value)

# Sort by the closest states to the mean value
df_closest_to_mean = df_1.sort_values(by='Difference_from_Mean').head(10)

# Display the mean value and the table of states closest to the mean
print(f"Mean Number of AI Job Postings: {mean_value:.2f}")
print(tabulate(df_closest_to_mean, headers='keys', tablefmt='psql'))
# Out:
# Mean Number of AI Job Postings: 9043.63
# +----+------------+-------------------------------------+------------------------+
# |    | US State   |   Number of AI job postings in 2023 |   Difference_from_Mean |
# |----+------------+-------------------------------------+------------------------|
# |  2 | AZ         |                                9022 |                21.6275 |
# |  5 | CO         |                               10292 |              1248.37   |
# | 34 | OH         |                               10409 |              1365.37   |
# | 24 | MO         |                                7390 |              1653.63   |
# | 47 | DC         |                                6861 |              2182.63   |
# |  0 | AL         |                                6214 |              2829.63   |
# | 22 | MN         |                                5824 |              3219.63   |
# | 36 | OR         |                                5478 |              3565.63   |
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

df_top10 = df_sorted[df_sorted['Year'] == 2023].head(10)
plot = df_top10.plot.bar(x='Skill cluster', y='AI job postings (% of all job postings)', figsize=(10, 5))
plot.set_title("AI Jobs by Percentage by Skills in 2023")
plot.set_ylabel("Percentage of AI job postings")
plot.set_xlabel("Skills")
plot.legend(loc="upper center")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data = pd.DataFrame({
    'State': ['DC', 'DE', 'MD', 'VA', 'MA', 'WA', 'CO', 'CA', 'NY', 'IL'],
    'Industry': ['Information', 'Scientific and Tech Services', 'Finance and Insurance', 'Manufacturing', 'Health Care and Social Assistance', 'Public Administration', 'Educational Services', 'Retail Trade', 'Construction', 'Construction'],
    'Year': [2021, 2022, 2023, 2023, 2021, 2022, 2023, 2023, 2021, 2022],
    'AI_Jobs': [5000, 3000, 4000, 2500, 4500, 3500, 3000, 2000, 1500, 1000],
    'Percentage_Growth': [10, 20, 15, 25, 30, 35, 40, 45, 50, 55],
    'Skills': ['Machine Learning', 'Artificial Intelligence', 'Natural language processing', 'Autonomous driving', 'Neural networks', 'Deep learning', 'Computer vision', 'Robotics', 'Data mining', 'Predictive analytics']
})

plt.figure(figsize=(10, 6))
sns.barplot(data=data, x='State', y='AI_Jobs', hue='Industry')
plt.title('AI Jobs by Industry and State')
plt.xlabel('State')
plt.ylabel('Number of AI Jobs')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.DataFrame({ 
    'State': ['DC', 'DE', 'MD', 'VA', 'MA', 'WA', 'CO', 'CA', 'NY', 'IL'],
    'Industry': ['Information', 'Scientific and Tech Services', 'Finance and Insurance', 'Manufacturing', 'Health Care and Social Assistance', 'Public Administration', 'Educational Services', 'Retail Trade', 'Construction', 'Construction'],
    'Year': [2021, 2022, 2023, 2023, 2021, 2022, 2023, 2023, 2021, 2022],
    'AI_Jobs': [5000, 3000, 4000, 2500, 4500, 3500, 3000, 2000, 1500, 1000],
    'Percentage_Growth': [10, 20, 15, 25, 30, 35, 40, 45, 50, 55],
    'Skills': ['Machine Learning', 'Artificial Intelligence', 'Natural language processing', 'Autonomous driving', 'Neural networks', 'Deep learning', 'Computer vision', 'Robotics', 'Data mining', 'Predictive analytics']
})

pivot_data = data.pivot(index='Industry', columns='State', values='AI_Jobs')
plt.figure(figsize=(10, 6))
heatmap = sns.heatmap(pivot_data, annot=True, fmt=".0f", cmap='YlGnBu')  

# Customize tick labels
heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation=45, ha="right", fontsize=12, fontweight='bold')
heatmap.set_yticklabels(heatmap.get_yticklabels(), rotation=0, fontsize=12, fontweight='bold')
labl = plt.ylabel('Industry', fontsize=14, fontweight='bold')
labl.set_color('red')
labl = plt.xlabel('State', fontsize=14, fontweight='bold')
labl.set_color('red')

# Use fmt=".0f" to format annotations as integers
plt.title('Heatmap of AI Jobs by Industry and State', fontsize=16, fontweight='bold', color='red')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample DataFrame for AI jobs by country
data_world = pd.DataFrame({
    'Country': ['USA', 'China', 'India', 'UK', 'Germany', 'France', 'Canada', 'Japan', 'South Korea', 'Australia'],
    'AI_Jobs': [12000, 8000, 9000, 7000, 6500, 5000, 4800, 4500, 4000, 3500]
})

plt.figure(figsize=(12, 8))
sns.barplot(data=data_world, x='Country', y='AI_Jobs', palette='viridis')
plt.title('AI Jobs by Country in 2023', color='red', fontsize=10, fontweight='bold')
plt.xlabel('Country', fontsize=10, fontweight='bold')
plt.ylabel('Number of AI Jobs', fontsize=10, fontweight='bold'),
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\madio\AppData\Local\Temp\ipykernel_20140\2423391971.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data_world, x='Country', y='AI_Jobs', palette='viridis')

# %%
import pandas as pd
import plotly.express as px

# Sample DataFrame with more countries (replace with your actual data)
data_world = pd.DataFrame({
    'Country': [
        'United States', 'China', 'India', 'United Kingdom', 'Germany', 'France', 
        'Canada', 'Japan', 'South Korea', 'Australia', 'Brazil', 'Russia', 'Mexico', 
        'South Africa', 'Italy', 'Spain', 'Netherlands', 'Sweden', 'Norway', 'Argentina',
        'Switzerland', 'Saudi Arabia', 'Turkey', 'Indonesia', 'Pakistan', 'Nigeria', 'Egypt'
    ],
    'AI_Jobs': [
        12000, 8000, 9000, 7000, 6500, 5000, 
        4800, 4500, 4000, 3500, 3000, 2800, 2600, 
        2400, 2200, 2000, 1800, 1600, 1400, 1200,
        1000, 900, 800, 700, 600, 500, 400
    ]
})

fig = px.choropleth(
    data_frame=data_world,
    locations='Country',
    locationmode='country names',
    color='AI_Jobs',
    hover_name='Country',
    hover_data={'AI_Jobs': True},
    color_continuous_scale=px.colors.sequential.Inferno,
    title='AI Jobs by Country in 2023'
)

fig.update_layout(
    title={
        'text': 'AI Jobs by Country in 2023',
        'y': 0.95,  # Position the title closer to the top of the figure
        'x': 0.5,  # Center the title
        'xanchor': 'center',
        'yanchor': 'top',
        'font': dict(color='red', size=24)  # Customize font color and size
    },
    geo=dict(
        showframe=False,
        showcoastlines=False,
        projection_type='equirectangular'  # Ensure a more uniform projection
    ),
    margin=dict(l=0, r=0, t=50, b=0)  # Adjust margins to reduce empty space
)

fig.show()
